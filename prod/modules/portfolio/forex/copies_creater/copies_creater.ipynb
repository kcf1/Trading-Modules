# %%
import shutil

import fileinput

# %%
def create_file_copy(source_file, destination_file, symbol, rate_name):
    try:
        shutil.copy(source_file, destination_file)
        print(f"Copy of {source_file} created successfully as {destination_file}.")

        # Replace code inside the copied file
        with fileinput.FileInput(destination_file, inplace=True) as file:
            for i, line in enumerate(file):
                print(
                    line.replace("EURUSD(Asset)", f"{symbol}(Asset)")
                    .replace(
                        'self.set_symbol("EURUSD")', f'self.set_symbol("{symbol}")'
                    )
                    .replace(
                        'self.set_usd_rate_name("USDUSD")',
                        f'self.set_usd_rate_name("{rate_name}")',
                    ),
                    end="",
                )

        print(f"Code replaced successfully in {destination_file}.")
    except IOError as e:
        print(f"Unable to create a copy of {source_file}: {e}")

# %%
symbols_rate = {
    "EURUSD": "USDUSD",
    "AUDUSD": "USDUSD",
    "AUDNZD": "NZDUSD",
    "NZDUSD": "USDUSD",
    "EURGBP": "GBPUSD",
    "GBPUSD": "USDUSD",
    "USDCAD": "USDCAD",
    "USDCHF": "USDCHF",
    "EURCHF": "USDCHF",
    "AUDCHF": "USDCHF",
    "AUDCAD": "USDCAD",
    "EURAUD": "AUDUSD",
    "AUDJPY": "USDJPY",
    "USDJPY": "USDJPY",
    "NZDCAD": "USDCAD",
    "NZDCHF": "USDCHF",
    "NZDJPY": "USDJPY",
    "EURNZD": "NZDUSD",
    "GBPNZD": "NZDUSD",
    "CADCHF": "USDCHF",
    "GBPCHF": "USDCHF",
    "EURCAD": "USDCAD",
    "EURJPY": "USDJPY",
    "USDILS": "USDILS",
    "GBPAUD": "AUDUSD",
    "CADJPY": "USDJPY",
    "GBPCAD": "USDCAD",
    "GBPJPY": "USDJPY",
    "CHFJPY": "USDJPY",
    "USDHKD": "USDHKD",
    "EURCZK": "USDCZK",
    "USDCZK": "USDCZK",
    "EURPLN": "USDPLN",
    "USDPLN": "USDPLN",
    "USDHUF": "USDHUF",
    "USDSEK": "USDSEK",
    "EURNOK": "USDNOK",
    "USDNOK": "USDNOK",
    "USDMXN": "USDMXN",
    "USDZAR": "USDZAR",
}

# %%
source_file = "eurusd.py"

for symbol, rate_name in symbols_rate.items():
    destination_file = f"{symbol.lower()}.py"
    create_file_copy(source_file, destination_file, symbol, rate_name)
# Out:
# Unable to create a copy of eurusd.py: 'eurusd.py' and 'eurusd.py' are the same file
# Copy of eurusd.py created successfully as audusd.py.
# Code replaced successfully in audusd.py.
# Copy of eurusd.py created successfully as audnzd.py.
# Code replaced successfully in audnzd.py.
# Copy of eurusd.py created successfully as nzdusd.py.
# Code replaced successfully in nzdusd.py.
# Copy of eurusd.py created successfully as eurgbp.py.
# Code replaced successfully in eurgbp.py.
# Copy of eurusd.py created successfully as gbpusd.py.
# Code replaced successfully in gbpusd.py.
# Copy of eurusd.py created successfully as usdcad.py.
# Code replaced successfully in usdcad.py.
# Copy of eurusd.py created successfully as usdchf.py.
# Code replaced successfully in usdchf.py.
# Copy of eurusd.py created successfully as eurchf.py.
# Code replaced successfully in eurchf.py.
# Copy of eurusd.py created successfully as audchf.py.
# Code replaced successfully in audchf.py.
# Copy of eurusd.py created successfully as audcad.py.
# Code replaced successfully in audcad.py.
# Copy of eurusd.py created successfully as euraud.py.
# Code replaced successfully in euraud.py.
# Copy of eurusd.py created successfully as audjpy.py.
# Code replaced successfully in audjpy.py.
# Copy of eurusd.py created successfully as usdjpy.py.
# Code replaced successfully in usdjpy.py.
# Copy of eurusd.py created successfully as nzdcad.py.
# Code replaced successfully in nzdcad.py.
# Copy of eurusd.py created successfully as nzdchf.py.
# Code replaced successfully in nzdchf.py.
# Copy of eurusd.py created successfully as nzdjpy.py.
# Code replaced successfully in nzdjpy.py.
# Copy of eurusd.py created successfully as eurnzd.py.
# Code replaced successfully in eurnzd.py.
# Copy of eurusd.py created successfully as gbpnzd.py.
# Code replaced successfully in gbpnzd.py.
# Copy of eurusd.py created successfully as cadchf.py.
# Code replaced successfully in cadchf.py.
# Copy of eurusd.py created successfully as gbpchf.py.
# Code replaced successfully in gbpchf.py.
# Copy of eurusd.py created successfully as eurcad.py.
# Code replaced successfully in eurcad.py.
# Copy of eurusd.py created successfully as eurjpy.py.
# Code replaced successfully in eurjpy.py.
# Copy of eurusd.py created successfully as usdils.py.
# Code replaced successfully in usdils.py.
# Copy of eurusd.py created successfully as gbpaud.py.
# Code replaced successfully in gbpaud.py.
# Copy of eurusd.py created successfully as cadjpy.py.
# Code replaced successfully in cadjpy.py.
# Copy of eurusd.py created successfully as gbpcad.py.
# Code replaced successfully in gbpcad.py.
# Copy of eurusd.py created successfully as gbpjpy.py.
# Code replaced successfully in gbpjpy.py.
# Copy of eurusd.py created successfully as chfjpy.py.
# Code replaced successfully in chfjpy.py.
# Copy of eurusd.py created successfully as usdhkd.py.
# Code replaced successfully in usdhkd.py.
# Copy of eurusd.py created successfully as eurczk.py.
# Code replaced successfully in eurczk.py.
# Copy of eurusd.py created successfully as usdczk.py.
# Code replaced successfully in usdczk.py.
# Copy of eurusd.py created successfully as eurpln.py.
# Code replaced successfully in eurpln.py.
# Copy of eurusd.py created successfully as usdpln.py.
# Code replaced successfully in usdpln.py.
# Copy of eurusd.py created successfully as usdhuf.py.
# Code replaced successfully in usdhuf.py.
# Copy of eurusd.py created successfully as usdsek.py.
# Code replaced successfully in usdsek.py.
# Copy of eurusd.py created successfully as eurnok.py.
# Code replaced successfully in eurnok.py.
# Copy of eurusd.py created successfully as usdnok.py.
# Code replaced successfully in usdnok.py.
# Copy of eurusd.py created successfully as usdmxn.py.
# Code replaced successfully in usdmxn.py.
# Copy of eurusd.py created successfully as usdzar.py.
# Code replaced successfully in usdzar.py.
